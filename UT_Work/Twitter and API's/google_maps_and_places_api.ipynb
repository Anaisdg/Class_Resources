# %%
# Create code to answer each of the following questions.
# Hint: You will need multiple target urls and multiple API requests.

# Dependencies
import requests
import json

# Google API Key
gkey = "AIzaSyDDvD0Y543t8I0Y5wPJdZIm_jmRt94xFmc"

# ------------------------------------------------------------------------------

# 1. What are the geocordinates (latitude and longitude) of Seattle,
# Washington?
target_city = "Seattle, Washington"

# Build URL using the Google Maps API
target_url = "https://maps.googleapis.com/maps/api/geocode/json" \
    "?address=%s&key=%s" % (target_city, gkey)

print("\r\nDrill #1")
print(target_url)

# Run request
seattle_geo = requests.get(target_url).json()

# Extract Lat/Lng
lat = seattle_geo["results"][0]["geometry"]["location"]["lat"]
lng = seattle_geo["results"][0]["geometry"]["location"]["lng"]

# Print results
print("%s: %s, %s" % (target_city, lat, lng))

# ------------------------------------------------------------------------------

# 2. What are the geocordinates (latitude and longitude) of The White House?
target_city = "The White House"

# Build URL using the Google Maps API
target_url = "https://maps.googleapis.com/maps/api/geocode/json" \
    "?address=%s&key=%s" % (target_city, gkey)

print("\r\nDrill #2")
print(target_url)

# Run request
dc_geo = requests.get(target_url).json()

# Extract Lat/Lng
lat = dc_geo["results"][0]["geometry"]["location"]["lat"]
lng = dc_geo["results"][0]["geometry"]["location"]["lng"]

# Print results
print("%s: %s, %s" % (target_city, lat, lng))

# ------------------------------------------------------------------------------

# 3. Find the names and addresses of a bike store in Seattle, Washington.
#    Hint: See https://developers.google.com/places/web-service/supported_types
target_type = "bicycle_store"
seattle_lat = 47.6062095
seattle_lng = -122.3320708

# Build URL using the Google Maps API
target_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json" \
    "?location=%s,%s&types=%s&radius=%s&key=%s" % (
        seattle_lat, seattle_lng, target_type, 8000, gkey)

print("\r\nDrill #3")
print(target_url)

# Run request
seattle_bikes = requests.get(target_url).json()

# Print the json (pretty printed)
# print(json.dumps(seattle_bikes, indent=4, sort_keys=True))

# Print the name and address of the first bike shop to appear
print(seattle_bikes["results"][0]["name"])
print(seattle_bikes["results"][0]["vicinity"])

# ------------------------------------------------------------------------------

# 4. Find a balloon store near the White House.
target_search = "Balloon Store"
dc_lat = 38.8976763
dc_lng = -77.0365298

# Build URL using the Google Maps API
target_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json" \
    "?location=%s,%s&keyword=%s&radius=%s&key=%s" % (
        dc_lat, dc_lng, target_search, 8000, gkey)

print("\r\nDrill #4")
print(target_url)

# Run request
dc_balloons = requests.get(target_url).json()

# Print the json (pretty printed)
# print(json.dumps(dc_balloons, indent=4, sort_keys=True))

# Print the name and address of the first baloon shop that appears
print(dc_balloons["results"][0]["name"])
print(dc_balloons["results"][0]["vicinity"])

# ------------------------------------------------------------------------------

# 5. Find the nearest dentist to your house.
# Hint: Use Google Maps to find your latitude and Google Places to find
# the dentist. You may also need the rankby property.
my_address = "151 Sip Ave"
target_search = "dentist"
target_url = "https://maps.googleapis.com/maps/api/geocode/json" \
    "?address=%s&key=%s" % (my_address, gkey)

print("\r\nDrill #5")
print(target_url)

my_geo = requests.get(target_url).json()
lat = my_geo["results"][0]["geometry"]["location"]["lat"]
lng = my_geo["results"][0]["geometry"]["location"]["lng"]

# print(lat)
# print(lng)
target_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json" \
    "?location=%s,%s&types=%s&rankby=distance&key=%s" % (
        lat, lng, target_search, gkey)

print(target_url)

# Run request
my_dentist = requests.get(target_url).json()

# Print the json (pretty printed)
# print(json.dumps(my_dentist, indent=4, sort_keys=True))

# Print the name and address of the first baloon shop that appears
print(my_dentist["results"][0]["name"])
print(my_dentist["results"][0]["vicinity"])

# ------------------------------------------------------------------------------


# 6. Bonus: Find the names and addresses of the top five places Google suggests
# for the phrase: "Happy Place ". Hint: Read about "Text Search Results"
# (https://developers.google.com/places/web-service/search#TextSearchRequests)
my_phrase = "Happy Place"
target_url = "https://maps.googleapis.com/maps/api/place/textsearch/json" \
    "?query=%s&key=%s" % (my_phrase, gkey)

print("\r\nDrill #6")
print(target_url)

happy_places = requests.get(target_url).json()
print(happy_places)
# print(json.dumps(happy_places, indent=4, sort_keys=True))

for place in range(5):
    print(happy_places["results"][place]["name"])
    print(happy_places["results"][place]["formatted_address"])
# Out:
# Drill #1
# https://maps.googleapis.com/maps/api/geocode/json?address=Seattle, Washington&key=AIzaSyDDvD0Y543t8I0Y5wPJdZIm_jmRt94xFmc
# Seattle, Washington: 47.6062095, -122.3320708
#
# Drill #2
# https://maps.googleapis.com/maps/api/geocode/json?address=The White House&key=AIzaSyDDvD0Y543t8I0Y5wPJdZIm_jmRt94xFmc
# The White House: 38.8976763, -77.0365298
#
# Drill #3
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=47.6062095,-122.3320708&types=bicycle_store&radius=8000&key=AIzaSyDDvD0Y543t8I0Y5wPJdZIm_jmRt94xFmc
# REI
# 222 Yale Avenue North, Seattle
#
# Drill #4
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.8976763,-77.0365298&keyword=Balloon Store&radius=8000&key=AIzaSyDDvD0Y543t8I0Y5wPJdZIm_jmRt94xFmc
# Party Depot
# 3513 South Jefferson Street, Falls Church
#
# Drill #5
# https://maps.googleapis.com/maps/api/geocode/json?address=151 Sip Ave&key=AIzaSyDDvD0Y543t8I0Y5wPJdZIm_jmRt94xFmc
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7309245,-74.0664116&types=dentist&rankby=distance&key=AIzaSyDDvD0Y543t8I0Y5wPJdZIm_jmRt94xFmc
# Giorgio T Di Vincenzo PC: Kim Nancy DDS
# 312 Academy Street # A, Jersey City
#
# Drill #6
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Happy Place&key=AIzaSyDDvD0Y543t8I0Y5wPJdZIm_jmRt94xFmc
# {'html_attributions': [], 'results': [{'formatted_address': 'Cecil St, South Melbourne VIC 3205, Australia', 'geometry': {'location': {'lat': -37.8323639, 'lng': 144.957271}, 'viewport': {'northeast': {'lat': -37.8310149197085, 'lng': 144.9586199802915}, 'southwest': {'lat': -37.8337128802915, 'lng': 144.9559220197085}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png', 'id': '365f19a2b8e2431f55b0637f75cc694e4896054d', 'name': 'Happy Place', 'opening_hours': {'open_now': False, 'weekday_text': []}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114421311081063804430/photos">Max Gross</a>'], 'photo_reference': 'CmRaAAAA-b0Omt6hXkthEoOAF4gnryUmDLz1qhfQxQlisWycf3_83B1cC_gtc8T8zfBoP-WKCJV6k2Aw5AO_cRi0hxpaB3S23nvfYKk-kWkdyWtsuXwSFxoc3KD465TLvPhsLoTnEhBC6Nk52igEwhk9c-auhyx_GhTgziH8zpyBkjb3ooTLisJQABCJaQ', 'width': 4032}], 'place_id': 'ChIJ89sd6f5n1moRj12gb0BW2bs', 'rating': 3.6, 'reference': 'CmRSAAAAED8bfK1jPVITuj5YglveegiHNFU7L_G1XPJDY51e3pXX7CrjsyWeXIEcxS77sGritynyzbibsBRbLEHEXG78JVzh62dRpANabttOq5XlugnFK0vYEvzt9bH3RcJXDwVZEhCszZmZfx6lO1WCrLEi4FWiGhTnJ_DMW9vgLdyW7BHRz40e-Znx8w', 'types': ['cafe', 'food', 'point_of_interest', 'establishment']}, {'formatted_address': '83 Randolph St, Rocklea QLD 4106, Australia', 'geometry': {'location': {'lat': -27.5636748, 'lng': 152.9982666}, 'viewport': {'northeast': {'lat': -27.5623700697085, 'lng': 152.9999250302915}, 'southwest': {'lat': -27.5650680302915, 'lng': 152.9972270697085}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png', 'id': '6b29f0e0b165da0ac9374c0dcacab40d7cbd333d', 'name': 'Happy Place 8', 'opening_hours': {'open_now': False, 'weekday_text': []}, 'photos': [{'height': 480, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106533969729703171973/photos">Happy Place 8</a>'], 'photo_reference': 'CmRaAAAAWurGPKyDG4efuVpKh7xIJkgJp7Sy0TP6V7DbUTssYCrAMs-WykxllVFak8RUw1pQQfJpISYQ2ngmmkBcy33Fhcvymdv5YSvDp0q0px-qCbxuFB6cE_v3Shaoy9YM_fIsEhA6v6_cRcOHgegYWHII2WDHGhTO0vIewtlbh17pnaLBs3Na5Nzq6g', 'width': 640}], 'place_id': 'ChIJAfPBXuxPkWsR5egJNZPHLJw', 'rating': 2.6, 'reference': 'CmRSAAAALbhzlEZrlhn-NI3Rp9kkcCrQ3oPDZnhC3cuVK2C465iUUDqJ3TudCfjvGQi9kUQutj9NbIDBtV1HJa27xV0TSKP8GkL0X9NlBOFcN9FOao3R-G78inhv5Cjj9PZsQcl2EhBGMym9SnGde2fzSEKnCNs3GhR__2jeb6ROXA45-zsDIRI_ogI7WA', 'types': ['point_of_interest', 'establishment']}, {'formatted_address': 'Spo Bangmalauw 7, ตำบล สาคู อำเภอ ถลาง ภูเก็ต 83110, Thailand', 'geometry': {'location': {'lat': 8.086609, 'lng': 98.30608699999999}, 'viewport': {'northeast': {'lat': 8.0879579802915, 'lng': 98.3074359802915}, 'southwest': {'lat': 8.085260019708496, 'lng': 98.30473801970848}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png', 'id': 'fa70fab30059bc332511f7e9c3def0d18256de04', 'name': 'The Happy Place Condominium', 'opening_hours': {'open_now': True, 'weekday_text': []}, 'photos': [{'height': 1520, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108889404023966763433/photos">Дмитрий Коека</a>'], 'photo_reference': 'CmRaAAAA_KjVf3iJOEkMtQ2xsNZkiLwyHnMy-nONrv0y7e0JWPdqzIXHBRs7LZ2uq-DQqKcUyR6PzzXjgtIJJ-ueErzzo7cItsjt_KdDWBY-hGmv-wz4YtbVdCS_47fOljLFNyjjEhAoVnWRcm90swrEetPBrsVMGhTl0U_GPY0BvRDy9G4C1ZdfHH9SQg', 'width': 2688}], 'place_id': 'ChIJs6zeidZHUDAR8raTZwJvIwE', 'rating': 4.3, 'reference': 'CmRRAAAAJAei-1ij-BwRRirTK362LInDn2hbhloMWoe435l9ipBN8UDwBNaWFhnsO7VzpeO6tcWdPETTlkVkL-jXZ0qM4GAjVtYuuZ3jECMGkQ_ElpuQQBM4bvYzG7cI6-oTsSJXEhAkfJTIH1kj6Q7rd1P1FxOqGhS1ZLA8_bsib7yOUTcpqdMKeDfc5Q', 'types': ['point_of_interest', 'establishment']}], 'status': 'OK'}
# Happy Place
# Cecil St, South Melbourne VIC 3205, Australia
# Happy Place 8
# 83 Randolph St, Rocklea QLD 4106, Australia
# The Happy Place Condominium
# Spo Bangmalauw 7, ตำบล สาคู อำเภอ ถลาง ภูเก็ต 83110, Thailand
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-3281e7ee4ad6> in <module>()
#     151
#     152 for place in range(5):
# --> 153     print(happy_places["results"][place]["name"])
#     154     print(happy_places["results"][place]["formatted_address"])
#
# IndexError: list index out of range

# %%
for y in np.arange()
